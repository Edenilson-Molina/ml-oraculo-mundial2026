# %% [markdown]
# # 03 - Modelado
# Entrenamiento y evaluacion se ejecutan desde src, no en el notebook.

# %%
# Ejecutar entrenamiento desde terminal
# python -m src.models.train

from pathlib import Path
import json

metrics_dir = Path("..") / "reports" / "metrics"

for path in metrics_dir.glob("*_metrics.json"):
    print(path.name)
    data = json.loads(path.read_text(encoding="utf-8"))
    print(data["test"])
# Out:
# The kernel failed to start as the Python Environment 'Python 3.14.4' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
# Ejemplo de lectura del modelo entrenado
import joblib

model_path = Path("..") / "models" / "trained" / "xgb.pkl"
if model_path.exists():
    model = joblib.load(model_path)
    print(model)
else:
    print("Modelo no encontrado aun")
# Out:
# The kernel failed to start as the Python Environment 'Python' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
