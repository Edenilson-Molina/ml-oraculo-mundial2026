# %% [markdown]
# # 02 - Preprocesamiento
# Uso del dataset procesado y feature engineering desde src.

# %%
import sys
from pathlib import Path

import pandas as pd

# Permite importar desde src/ cuando el notebook corre en notebooks/
PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.features.feature_engineering import build_feature_matrix

DATA_PATH = PROJECT_ROOT / "data" / "processed" / "final_dataset.csv"

df = pd.read_csv(DATA_PATH)
df["date"] = pd.to_datetime(df["date"])

# %%
# Construir la matriz de características
df_features, feature_cols = build_feature_matrix(df, include_elo=True, apply_decay=True, form_window=5)

# Mostrar las columnas de características
feature_cols
# Out:
# 2026-05-23 19:07:36,743 | INFO | src.features.feature_engineering | Adding ELO features
# 2026-05-23 19:07:38,468 | INFO | src.features.feature_engineering | Adding recent form features
# 2026-05-23 19:07:38,986 | INFO | src.features.feature_engineering | Adding basic diff features
# 2026-05-23 19:07:39,008 | INFO | src.features.feature_engineering | Applying time decay
# ['rank_diff',
#  'elo_diff',
#  'market_value_diff',
#  'avg_age_diff',
#  'squad_size_diff',
#  'top5_players_diff',
#  'home_advantage',
#  'form_win_rate_diff',
#  'form_goal_diff_diff',
#  'form_gf_avg_diff',
#  'form_ga_avg_diff']

# %%
leakage_cols = ["home_score", "away_score"]

[c for c in leakage_cols if c in df_features.columns]
# Out:
# ['home_score', 'away_score']
